# %%
'''4)
Create a Linear Regression Model using Python/R to predict home prices using Boston Housing 
Dataset. The Boston Housing dataset contains information about various houses in Boston through different parameters. There are 506 samples and 14 feature variables in this dataset.
'''

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

boston=pd.read_csv(r"housing.csv")
boston
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# Load your dataset (replace this with your dataset loading code)
data = pd.read_csv(r"housing.csv")

# Define features (X) and target variable (y)
X = data[['total_rooms', 'population']]
y = data['median_house_value']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Create and fit the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Predict the target variable for the test set
y_pred = model.predict(X_test)

# Visualize the predicted values against the actual values
plt.scatter(y_test, y_pred, c='red')
plt.xlabel("True Price ($100)")
plt.ylabel("Predicted Price ($100)")
plt.title("True Price vs Predicted Price")
plt.show()

# Example prediction using specific features
features = np.array([[6,19]])  # Use the same features as used during training
prediction = model.predict(features)
print(f"Prediction of house price using features {features}: {prediction}")
# Out:
# Prediction of house price using features [[ 6 19]]: [200868.32046215]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

dataset=pd.read_csv(r"housing.csv")
dataset

#sns.heatmap(dataset,corr(),annot=True)

X=dataset[["total_rooms","population"]]
y=dataset["median_house_value"]
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

print(X_train)
print(X_test)
print(y_train)
print(y_test)

from sklearn.linear_model import LinearRegression

model=LinearRegression()

model.fit(X_train,y_train)

y_pred = model.predict(X_test)
y_pred

plt.scatter(y_test,y_pred,c='skyblue')
plt.xlabel("True price$1000")
plt.ylabel("predicted price")
plt.title("true price vs predicted price")
plt.show()

features=np.array([[6,19]])
prediction=model.predict(features)

print(f"Prediction for housing price{features}:{prediction}")
# Out:
#        total_rooms  population
# 12069        502.0       228.0
# 15925       2381.0      1485.0
# 11162       1718.0      1022.0
# 4904         697.0       749.0
# 4683        2373.0      1135.0
# ...            ...         ...
# 13123       1314.0       712.0
# 19648       1118.0       647.0
# 9845        1431.0       704.0
# 10799       2125.0      1052.0
# 2732        1171.0      1024.0
#
# [16512 rows x 2 columns]
#        total_rooms  population
# 14740       2101.0      1551.0
# 10101       2620.0      1296.0
# 20566       3167.0      1554.0
# 2670         709.0       390.0
# 15709       1637.0       649.0
# ...            ...         ...
# 6655        2682.0      2050.0
# 3505        1453.0       808.0
# 1919        1720.0       850.0
# 1450        2739.0      1072.0
# 4148        1580.0      1462.0
#
# [4128 rows x 2 columns]
# 12069    500001.0
# 15925    270000.0
# 11162    196100.0
# 4904     118800.0
# 4683     225000.0
#            ...
# 13123    144600.0
# ...
